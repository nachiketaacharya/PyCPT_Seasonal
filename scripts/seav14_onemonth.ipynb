# %% [markdown]
# ## PyCPT_seasonal --4 May 2020
# ## Produce seasonal (un)calibrated forecasts and assess associated skill
#
# This version is a modified version of original PyCPT for seasonal forecast
#
# #### Authors:
#  Kyle Joseph Chen Hall and Nachiketa Acharya
#
# #### Original Authors:
# Ángel G. Muñoz (agmunoz@iri.columbia.edu), Andrew W. Robertson (awr@iri.columbia.edu), Simon J. Mason (simon@iri.columbia.edu)
#
# #### Acknowledgements:
# Rémi Cousin (IRI) for key Ingrid code development and support.
# Xandre Chourio (IRI) for Windows and code support, and testing.
# James Doss-Gollin (Columbia Water Center) developed the original download Python functions.
# Part of the effort to develop PyCPT is funded by the Columbia World Project "Adapting Agriculture to Climate Today, for Tomorrow" (ACToday), and NOAA MAPP's projects NA18OAR4310275 (Muñoz) and NA16OAR4310145 (Robertson).
#
# #### Version log
# * It produce probabailisitc and determinisitc forecast map.
# * It included ENACTS data for Bangladesh.
# * It include more data for train CCA.
# * It fixed EOF plot.
#
# #### Input:
# * Predictor is rainfall from NMME models
# * Predictand is either rainfall total or frequency of rainy days from CHIRPS or CPC or ENACTS etc
#
# #### Output:
# * Several skill maps for assessment of deterministic forecast AND forecast maps, in the output folder.
# * CPT scripts used to assess skill, in the scripts folder.
# * Downloaded input files, in the input folder.
#
# #### Notes:
# 1. Old data in the input folder is deleted at the beginning of the process!
#
# ### Namelist section

# %%
########Work name (name of the work folder; e.g., one word followed by "_seasonal":)
work='AUG_Jul_CCA_ENACTS'

########Model (choose one, a subset or all models: 
#CMC1-CanCM3, CMC2-CanCM4,  COLA-RSMAS-CCSM4*, 
# GFDL-CM2p5-FLOR-A06*, GFDL-CM2p5-FLOR-B01*,GFDL-CM2p1-aer04*, NASA-GEOSS2S*, NCEP-CFSv2*)
#The ones with "*" are producing operation#al forecasts, the others are frozen. 
models=['CanSIPSv2','COLA-RSMAS-CCSM4', 'GFDL-CM2p5-FLOR-A06', 'GFDL-CM2p5-FLOR-B01', 'NASA-GEOSS2S','NCEP-CFSv2']
#models=['CanSIPSv2']

########Obs (choose between CPC-CMAP-URD, CHIRPS, TRMM, CPC, Chilestations,GPCC)
obs='ENACTS-BD'
#obs='CHIRPS'
station=False

########MOS method (choose between None, PCR, CCA) #Esto es calibracion
MOS='CCA' 

#only used if MOS == 'CCA' or MOS == 'PCR'
xmodes_min = 1
xmodes_max = 8
ymodes_min = 2
ymodes_max = 10
ccamodes_min = 1
ccamodes_max = 5

########Predictand (choose between PRCP, RFREQ)
PREDICTAND='PRCP'

########Predictor (choose between GCM's PRCP, VQ, UQ)
#VQ and UQ only works with models=['NCEP-CFSv2']
PREDICTOR='PRCP'

########Target seasons and related parameters
##If more targets, increase the arrays accordingly
#mons=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
mons=['Jul']
tgti='1.5'  #S: start for the DL
tgtf='1.5'   #S: end for the DL
#for now, just write the target period (for DL)
#tgts=['Feb-Apr','Mar-May','Apr-Jun','May-Jul','Jun-Aug','Jul-Sep','Aug-Oct','Sep-Nov','Oct-Dec','Nov-Jan','Dec-Feb','Jan-Mar'] 
tgts=['Aug']

tini = 1982
tend = 2018

########Forecast date  
monf='Jul' 	# Initialization month 
fyr=2020 	# Forecast year

########Switches: 
force_download = False   #force download of data files, even if they already exist locally --- IF YOU ALREADY HAVE OBS FILES, DOUBLE CHECK WHICH ONES THEY ARE --- True to be safe

# ########Spatial domain for predictor
nla1=35 	# Northernmost latitude
sla1=15 	# Southernmost latitude
wlo1=80 	# Westernmost longitude
elo1=100 	# Easternmost longitude
# Spatial domain for predictand
nla2=28 	# Northernmost latitude
sla2=20 	# Southernmost latitude
wlo2=87 	# Westernmost longitude
elo2=94 	# Easternmost longitude

# %%
########Some folder and file options:
# Working directory --it should exist!!!
workdir = '/Users/kylehall/Projects/PyCPT-Dev/scripts/'
# PATH to CPT root directory
cptdir='/Users/kylehall/Projects/PyCPT-Dev/CPT/16.4.1/'
    
print("PyCPT folder is:")
# %cd $workdir
# !mkdir -p $work
# Out:
# PyCPT folder is:
# /Users/kylehall/Projects/PyCPT-Dev/scripts

# %% [markdown]
# ### End of namelist section  (do not modify anything below this line)

# %% [markdown]
# #### Load Libraries

# %%
import os
import sys
import xarray as xr
import numpy as np
import pandas as pd
import subprocess
from pycpt_functions_seasonal import *
from scipy.stats import t
if MOS=='ELR':
    from sklearn.linear_model import LogisticRegression
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import calendar

########Set Up Useful Variables Automatically 
rainfall_frequency, threshold_pctle, wetday_threshold, obs_source, hdate_last,\
 mpref, L, ntrain, fprefix, nmonths, ndays = setup_params(PREDICTOR,obs,MOS,tini,tend, tgts)

print("Python libraries loaded")
print("Now in the work folder:")
# %cd $work
workdir = os.getcwd()
# Out:
# /Users/kylehall/anaconda/envs/pycpt_env37/lib/python3.7/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)
# Predictand is Rainfall Total (mm)
# Python libraries loaded
# Now in the work folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS

# %%
print("Creating working folders, if not already there...")
print("Work directory is:")
# %cd $workdir
# !mkdir -p input
# !mkdir -p output
# !mkdir -p scripts
# !rm -Rf scripts/*

# Set up CPT environment
os.environ["CPT_BIN_DIR"] = cptdir
print("CPT environment loaded...")
#print("CPT version is "+str(wetday_threshold))
# Out:
# Creating working folders, if not already there...
# Work directory is:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS
# CPT environment loaded...

# %% [markdown]
# ## Check if domains are ok --if you don't like them, go back to the namelist and modify them

# %%
print("Training period: "+str(tini)+"-"+str(tend))
print("Forecast initialized on: "+monf+" "+str(fyr))
#Plot domains
pltdomain(wlo1,elo1,nla1,sla1,wlo2,elo2,nla2,sla2)
# Out:
# Training period: 1982-2018
# Forecast initialized on: Jul 2020

# %% [markdown]
# # Download data if necessary, and run CPT

# %%
#mons=['Jan','Dec']
mons=['Jul']
tgti='1.5'  #S: start for the DL
tgtf='1.5'   #S: end for the DL
#for now, just write the target period (for DL)
#tgts=['Feb-Apr','Jan-Mar'] 
tgts=['Aug']

#If downloadling data from several models, this section might take a while to be done
for model in models:
    print('')
    print('')
    print('----Starting process for '+model+'----')
    #for mon in mons:
        #tar=tgts[mons.index(mon)]
    for i in range(len(mons)):
        tar, mon = tgts[i], mons[i]
    
        print("New folder:")
        # %cd $workdir/input

        print('Preparing CPT files for '+model+' and initialization '+mon+'...')
        PrepFiles(fprefix, PREDICTAND, threshold_pctle, wlo1, wlo2,elo1, elo2, sla1, sla2, nla1, nla2, tgti, tgtf, mon, monf, fyr, os, wetday_threshold, tar, model, obs_source, hdate_last, force_download,station,ndays, nmonths, tini, tend)
 
        print("New folder:")
        # %cd $workdir/scripts

        CPTscript(model,PREDICTAND, mon,monf, fyr, nla1,sla1,wlo1,elo1,nla2,sla2,wlo2,elo2,fprefix,mpref,tar,ntrain,MOS,station, xmodes_min, xmodes_max, ymodes_min, ymodes_max, ccamodes_min, ccamodes_max, tini, tend)

        print('Executing CPT for '+model+' and initialization '+mon+'...')
        try:
            subprocess.check_output(cptdir+'CPT.x < params > CPT_stout_train_'+model+'_'+tar+'_'+mon+'.txt',stderr=subprocess.STDOUT, shell=True)
        except subprocess.CalledProcessError as e:
            print(e.output.decode())
            raise
        print('----------------------------------------------')
        print('Calculations for '+mon+' initialization completed!')
        print('See output folder, and check scripts/CPT_stout_train_'+model+'_'+tar+'_'+mon+'.txt for errors')
        print('----------------------------------------------')
        print('----------------------------------------------')

print('')
print('')
print('')
print('\033[1mPROCESS COMPLETED \033[0;0m')
# Out:
# ----Starting process for CanSIPSv2----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for CanSIPSv2 and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for CanSIPSv2 and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_CanSIPSv2_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
# ----Starting process for COLA-RSMAS-CCSM4----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for COLA-RSMAS-CCSM4 and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for COLA-RSMAS-CCSM4 and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_COLA-RSMAS-CCSM4_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
# ----Starting process for GFDL-CM2p5-FLOR-A06----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for GFDL-CM2p5-FLOR-A06 and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for GFDL-CM2p5-FLOR-A06 and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_GFDL-CM2p5-FLOR-A06_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
# ----Starting process for GFDL-CM2p5-FLOR-B01----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for GFDL-CM2p5-FLOR-B01 and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for GFDL-CM2p5-FLOR-B01 and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_GFDL-CM2p5-FLOR-B01_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
# ----Starting process for NASA-GEOSS2S----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for NASA-GEOSS2S and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for NASA-GEOSS2S and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_NASA-GEOSS2S_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
# ----Starting process for NCEP-CFSv2----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for NCEP-CFSv2 and initialization Jul...
# Hindcasts file ready to go
# ----------------------------------------------
# Obs:precip file ready to go
# ----------------------------------------------
# Forecasts file ready to go
# ----------------------------------------------
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for NCEP-CFSv2 and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_NCEP-CFSv2_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
#
# PROCESS COMPLETED

# %% [markdown]
# ## Deterministic Skill Analysis

# %%
#####Choose metrics (options are: 'Pearson','Spearman','2AFC','RocAbove','RocBelow', 'RMSE'):
met=('Pearson','Spearman','2AFC','RocAbove','RocBelow', 'RMSE')
#monss=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']   #Needs to be any of the seasons computed.
monss=['Aug'] 

print("Present folder:")
# %cd $workdir/output

# Skill scores loop
plt.rcParams.update({'font.size': 11})
for ime in met:
    pltmap(models,PREDICTAND,ime,wlo2,elo2,sla2,nla2,fprefix,mpref,tgts,mons,monss, obs)   
    print('')
    print("\033[1m"+ime+"\033[0;0m")
    #plt.show()
    print('')
    plt.savefig("1_"+ime+".png",dpi=300)
    #plt.close()
    plt.show()
# Out:
# Present folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
#
# Pearson
# Spearman
# 2AFC
# RocAbove
# RocBelow
# RMSE

# %% [markdown]
# ##### EOF Analysis (only available if MOS=PCR or CCA)

# %%
#monss=['Dec-Feb','Mar-May','Jun-Aug','Sep-Nov']   #Needs to be any of the seasons computed.
monss=['Aug'] 

print("Present folder:")
# %cd $workdir/output
print('')
print('')

# Skill scores loop
plt.rcParams.update({'font.size': 11})
nmodes=3
for imod in range(nmodes):
    plteofs(models,PREDICTAND,imod,nmodes,wlo1,elo1,sla1,nla1,fprefix,mpref,tgts, mons,monss,fyr, obs)  #try to plot predictor domain 
    print("Mode "+str(imod+1))
    #plt.show()
    plt.savefig("2_eof"+str(imod+1)+".png",dpi=300)
    #plt.close()
    plt.show()
# Out:
# Present folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
#
#
# Mode 1
# Mode 2
# Mode 3

# %% [markdown]
# ## Multi-model ensemble: NextGen

# %%
#List of selected models:
#models=['CMC2-CanCM4', 'GFDL-CM2p5-FLOR-A06','NCEP-CFSv2']
#models=['CMC1-CanCM3', 'CMC2-CanCM4', 'COLA-RSMAS-CCSM4', 'GFDL-CM2p5-FLOR-A06', 'GFDL-CM2p5-FLOR-B01', 'NASA-GEOSS2S', 'NCEP-CFSv2']
#models=['GFDL-CM2p5-FLOR-A06']

models=['CanSIPSv2','COLA-RSMAS-CCSM4', 'GFDL-CM2p5-FLOR-A06', 'GFDL-CM2p5-FLOR-B01', 'NASA-GEOSS2S','NCEP-CFSv2']
#models=['CanSIPSv2']

# %%
print('----Assessing skill for NextGen----')
model='NextGen'
MOS='None'   #we're changing here to no MOS to assess skill of NextGen
file='FCST_xvPr'

for mon in mons:
    tar=tgts[mons.index(mon)]
    print("New folder:")
    # %cd $workdir/input

    print('Preparing CPT files for '+model+' and initialization '+mon+'...')
    NGensemble(models,fprefix,PREDICTAND,mpref,file,tar,mon,tgti,tgtf,monf,fyr)
    
    print("New folder:")
    # %cd $workdir/scripts

    CPTscript(model,PREDICTAND, mon,monf, fyr, nla1,sla1,wlo1,elo1,nla2,sla2,wlo2,elo2,fprefix,mpref,tar,ntrain,MOS,station, xmodes_min, xmodes_max, ymodes_min, ymodes_max, ccamodes_min, ccamodes_max, tini, tend)

    print('Executing CPT for '+model+' and initialization '+mon+'...')
    try:
        subprocess.check_output(cptdir+'CPT.x < params > CPT_stout_train_'+model+'_'+tar+'_'+mon+'.txt',stderr=subprocess.STDOUT, shell=True)
    except subprocess.CalledProcessError as e:
        print(e.output.decode())
        raise
    print('----------------------------------------------')
    print('Calculations for '+mon+' initialization completed!')
    print('See output folder, and check scripts/CPT_stout_train_'+model+'_'+tar+'_'+mon+'.txt for errors')
    print('----------------------------------------------')
    print('----------------------------------------------')

print('')
print('')
print('')
print('\033[1mPROCESS COMPLETED \033[0;0m')
# Out:
# ----Assessing skill for NextGen----
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/input
# Preparing CPT files for NextGen and initialization Jul...
# Cross-validated prediction files successfully produced
# New folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/scripts
# Executing CPT for NextGen and initialization Jul...
# ----------------------------------------------
# Calculations for Jul initialization completed!
# See output folder, and check scripts/CPT_stout_train_NextGen_Aug_Jul.txt for errors
# ----------------------------------------------
# ----------------------------------------------
#
#
#
# PROCESS COMPLETED

# %%
#####Choose metrics (options are: 'Pearson','Spearman','2AFC','RocAbove','RocBelow'):
met=('Pearson','Spearman','2AFC','RocAbove','RocBelow', 'RMSE')
#monss=['Dec-Feb','Mar-May','Apr-Jun','Sep-Nov']   #Needs to be any of the seasons computed.
monss=['Aug'] 
modelo=['NextGen']

print("Present folder:")
# %cd $workdir/output

# Skill scores loop
plt.rcParams.update({'font.size': 11})
for ime in met:
    pltmap(modelo,PREDICTAND,ime,wlo2,elo2,sla2,nla2,fprefix,mpref,tgts,mons,monss, obs)   
    print('')
    print("\033[1m"+ime+"\033[0;0m")
    #plt.show()
    print('')
    plt.savefig("3_nextGen"+ime+".png",dpi=300)
    plt.show()
# Out:
# Present folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
#
# Pearson
# Spearman
# 2AFC
# RocAbove
# RocBelow
# RMSE

# %% [markdown]
# # Real-Time Forecast

# %%
print("Folder:")
# %cd $workdir/output

plt_ng_deterministic(models, PREDICTAND, wlo2,elo2,sla2,nla2, fprefix, mpref, monss, mon, fyr)
plt_ng_probabilistic(models, PREDICTAND, wlo2,elo2,sla2,nla2, fprefix, mpref, monss, mon, fyr)
# Out:
# Folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output

# %%
print("Present folder:")
# %cd $workdir/output
ensemblefiles(modelo,work)
# Out:
# Present folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
# cp: ../*NextGen*.txt: No such file or directory
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a COLA-RSMAS-CCSM4_RFCST_PRCP_Aug_iniJul2020.txt
# a COLA-RSMAS-CCSM4_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a CanSIPSv2_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a CanSIPSv2_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a CanSIPSv2_RFCST_PRCP_Aug_iniJul2020.txt
# a CanSIPSv2_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-A06_RFCST_PRCP_Aug_iniJul2020.txt
# a GFDL-CM2p5-FLOR-A06_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a GFDL-CM2p5-FLOR-B01_RFCST_PRCP_Aug_iniJul2020.txt
# a GFDL-CM2p5-FLOR-B01_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a NASA-GEOSS2S_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a NASA-GEOSS2S_RFCST_PRCP_Aug_iniJul2020.txt
# a NASA-GEOSS2S_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a NCEP-CFSv2_PRCP_CCAFCST_Obs_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCAFCST_P_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCAFCST_mu_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCAFCST_var_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCAFCST_xvPr_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCAFCST_z_Aug_Jul2020.txt
# a NCEP-CFSv2_PRCP_CCA_2AFC_Aug_Jul2020.txt
# a NCEP-CFSv2_RFCST_PRCP_Aug_iniJul2020.txt
# a NCEP-CFSv2_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# a NextGen_RFCST_PRCP_Aug_iniJul2020.txt
# a NextGen_RFCST_reliabdiag_PRCP_Aug_iniJul2020.tsv.txt
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
# Compressed file AUG_Jul_CCA_ENACTS_NextGen.tgz created in output/NextGen/
# Now send that file to your contact at the IRI

# %% [markdown]
# ### Flexible Forecasts

# %%
flexformat_threshold = 100 #threshold for the flexible format map

#CPC: Al parecer lluvia total trimestral
#CHIRPS: mm/dia

print("Folder:")
# %cd $workdir/output
plt.rcParams.update({'font.size': 12})
pltmapff(models,PREDICTAND,flexformat_threshold,ntrain,wlo2,elo2,sla2,nla2,fprefix,mpref,monf,fyr,mons,tgts)
#plt.savefig("ProbFcst_Flex.pdf", dpi=300)
# Out:
# Folder:
# /Users/kylehall/Projects/PyCPT-Dev/scripts/AUG_Jul_CCA_ENACTS/output
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f49283b4b7fb> in <module>
#       7 get_ipython().run_line_magic('cd', '$workdir/output')
#       8 plt.rcParams.update({'font.size': 12})
# ----> 9 pltmapff(models,PREDICTAND,flexformat_threshold,ntrain,wlo2,elo2,sla2,nla2,fprefix,mpref,monf,fyr,mons,tgts)
#      10 #plt.savefig("ProbFcst_Flex.pdf", dpi=300)
#
# TypeError: pltmapff() missing 1 required positional argument: 'obs'

# %%
#flexformat_threshold = 10. #threshold for the flexible format map (in mm/week)
lon=90
lat=23
 
print("Folder:")
# %cd $workdir/output
plt.rcParams.update({'font.size': 12})
pltprobff(models,PREDICTAND,flexformat_threshold,ntrain,lon,lat,wlo2,elo2,sla2,nla2,fprefix,mpref,monf,fyr,mons,tgts)
plt.savefig("ProbExceed.pdf", dpi=300)

# %%
models,fprefix,predictand,mpref,id,tar,mon,tgti,tgtf,monf,fyr
